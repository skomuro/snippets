# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and axes
fig, ax = plt.subplots()
data = np.random.random((5, 5)) 
# Create the heatmap
heatmap = ax.imshow(data, cmap=cm.hot_r, extent = [0,1,0,1])
# Add a colorbar
colorbar = plt.colorbar(heatmap)

# Customize the colorbar
ax.set_title("MC")
colorbar.ax.set_ylabel('', fontsize='large')
ax.set_xlabel(r"$\beta$")
ax.set_ylabel(r"$\lambda$")
ax.set_xticks(np.linspace(0,1,11))
ax.set_yticks(np.linspace(0,1,11))
# Show the plot
#plt.savefig("../figures/Granell2013/MC_diagram")
# Out:
# [<matplotlib.axis.YTick at 0x7fb5a8249640>,
#  <matplotlib.axis.YTick at 0x7fb5a8249190>,
#  <matplotlib.axis.YTick at 0x7fb5a8227b50>,
#  <matplotlib.axis.YTick at 0x7fb5b95681c0>,
#  <matplotlib.axis.YTick at 0x7fb5b9568910>,
#  <matplotlib.axis.YTick at 0x7fb5b956e0a0>,
#  <matplotlib.axis.YTick at 0x7fb5b956e7f0>,
#  <matplotlib.axis.YTick at 0x7fb5b95689d0>,
#  <matplotlib.axis.YTick at 0x7fb5b95553d0>,
#  <matplotlib.axis.YTick at 0x7fb5b956e190>,
#  <matplotlib.axis.YTick at 0x7fb5b9577490>]
